# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("areezvisram12/fifa-world-cup-2026-match-data-unofficial")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 6.93k/6.93k [00:00<00:00, 4.53MB/s]
# Extracting files...
# Path to dataset files: /Users/mb_pro/.cache/kagglehub/datasets/areezvisram12/fifa-world-cup-2026-match-data-unofficial/versions/3

# %%
# Download latest version
path = kagglehub.dataset_download("areezvisram12/fifa-world-cup-2026-match-data-unofficial", output_dir="date_kaggle_world_cup")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 6.93k/6.93k [00:00<00:00, 2.17MB/s]
# Extracting files...
# Path to dataset files: date_kaggle_world_cup
