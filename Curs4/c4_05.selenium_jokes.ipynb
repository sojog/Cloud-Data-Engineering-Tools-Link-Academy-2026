# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
URL = "https://icanhazdadjoke.com/"

browser = webdriver.Chrome()
browser.get(URL)

# %%
browser.find_elements(By.CLASS_NAME, "fc-button-label")[0].click()

# %%
browser.find_elements(By.CLASS_NAME, "subtitle")[0].text
# Out:
# 'icanhazdadjoke'

# %%
browser.find_elements(By.CLASS_NAME, "subtitle")[1].text
# Out:
# 'I used to hate facial hair, but then it grew on me.'

# %%
browser.find_element(By.CLASS_NAME, "subtitle").text
# Out:
# 'icanhazdadjoke'

# %%
browser.refresh()

# %%
browser.get(URL)

# %%
browser.find_element(By.XPATH, "/html/body/section/div/div[1]/div[2]/a/span[2]").click()

# %%
browser.quit()
