# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
URL = "https://www.olx.ro/d/oferta/masina-de-cusut-singer-din-anul-1896-IDkAvYh.html"

# %%
browser = webdriver.Chrome()

# %%
browser.get(URL)

# %%
browser.quit()

# %%
accept_button = browser.find_element(By.ID, "onetrust-accept-btn-handler")
accept_button.click()

# %%
pret = browser.find_element(By.CLASS_NAME, "css-j7prh4")
pret
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="b6c98b008c9f4b06e4011ba2d168916a", element="f.2CF54FB591155EBB71288A54FD9D8D42.d.4F8004B252BB176929E0732E360E126B.e.109")>

# %%
pret.text
# Out:
# '1 500 lei'

# %%
browser.get("https://cursbnr.ro")

# %%
browser.find_element(By.CLASS_NAME, "fc-button-label").click()

# %%
value_elements = browser.find_elements(By.CLASS_NAME, "value")
value_elements
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b6c98b008c9f4b06e4011ba2d168916a", element="f.2CF54FB591155EBB71288A54FD9D8D42.d.A0128939098A6BA995D4AC162EA2B2A1.e.1192")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b6c98b008c9f4b06e4011ba2d168916a", element="f.2CF54FB591155EBB71288A54FD9D8D42.d.A0128939098A6BA995D4AC162EA2B2A1.e.1195")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b6c98b008c9f4b06e4011ba2d168916a", element="f.2CF54FB591155EBB71288A54FD9D8D42.d.A0128939098A6BA995D4AC162EA2B2A1.e.1200")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b6c98b008c9f4b06e4011ba2d168916a", element="f.2CF54FB591155EBB71288A54FD9D8D42.d.A0128939098A6BA995D4AC162EA2B2A1.e.1214")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b6c98b008c9f4b06e4011ba2d168916a", element="f.2CF54FB591155EBB71288A54FD9D8D42.d.A0128939098A6BA995D4AC162EA2B2A1.e.1219")>,
# ...

# %%
for elem in value_elements:
    print(elem.text)
# Out:
# 1 EURO = 5.2432 Lei
# 1 USD = 4.5097 Lei
# 1 EURO = 1.1626 USD
# 3M (3 luni): 5.84%
# 6M (6 luni): 5.92%
# 12M (12 luni): 5.98%
# 1 GBP = 6.0612 Lei
# 1 GBP = 1.3440 USD

# %%
browser.quit()
